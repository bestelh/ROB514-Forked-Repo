# %%
# Initialize Otter
import otter
grader = otter.Notebook("a_start_here_libraries.ipynb")

# %% [markdown]
# ## Ensuring the libararies are installed correctly
#
# Use this JN to check that all your libraries are installed correctly, and to install any that are not.
#
# First thing to note: See the "Select Kernel" in the upper-right hand corner? This needs to be set to the Python version you setup in the instructions:
#
# https://docs.google.com/document/d/1Cp4uuRHMWHfKTAbYAV14y2tMWslmj_-bv_xo3CxYGAo/edit?usp=sharing
#
# Presumably, if you are reading this, than you have already set up VSCode and done the library installs in the above document.
#
# Note: If you are using this file to "fix" library problems, first make sure that whatever you've selected in "Select Kernel" is the same for both JNs.

# %%
# These are all the imports you'll need in the class; if you get a "library not found" then see the following cells for installing them

# Note: You may get a pop-up that says "ipykernel needed, install y/n". Say yes. That's the library that lets you run cells in a JN.
#  For Mac users with Apple silicon: That install will likely Fail - you will need to follow the instructions to over-ride the
#    system checks (at least as-of spring 2025). Go back to the install doc (above) and follow the instructions for how to do that.
#  If you've already done it, then chances are that when you did Select Kernel you did not pick the same kernel as the one you
#    did the homebrew install with. Double check that they are the same by typing "python3 --version" into a terminal - that one
#    should be the same as the one you picked for Select Kernel
import otter
import numpy
import matplotlib
import scipy
import json

# %% [markdown]
# If all of the above imports worked, then you're done! If not, you can use the following cell to force-install the missing libraries
#
# This may take awhile, btw

# %%
import sys
# !{sys.executable} -m pip install otter-grader
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install scipy
# !{sys.executable} -m pip install json
# Out:
# Requirement already satisfied: otter-grader in c:\users\beach\appdata\roaming\python\python311\site-packages (6.1.6)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (8.3.0)
# Requirement already satisfied: dill>=0.3.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (0.4.0)
# Requirement already satisfied: fica>=0.4.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (0.4.1)
# Requirement already satisfied: ipylab<2.0.0,>=1.0.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (1.1.0)
# Requirement already satisfied: ipython in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (9.6.0)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.1.5 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (8.1.7)
# Requirement already satisfied: jinja2<4.0,>=3.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (3.1.6)
# Requirement already satisfied: jupytext<2.0.0,>=1.16.4 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (1.17.3)
# Requirement already satisfied: nbconvert[webpdf]>=6.0.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (7.16.6)
# Requirement already satisfied: nbformat>=5.0.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (5.10.4)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (2.3.3)
# Requirement already satisfied: python-on-whales<1.0.0,>=0.72.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (0.78.0)
# Requirement already satisfied: pyyaml<7,>=6 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (6.0.3)
# Requirement already satisfied: requests<3.0,>=2.31 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (2.32.5)
# Requirement already satisfied: wrapt<2.0.0,>=1.16.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from otter-grader) (1.17.3)
# Requirement already satisfied: colorama in c:\users\beach\appdata\roaming\python\python311\site-packages (from click<9.0.0,>=8.1.7->otter-grader) (0.4.6)
# Requirement already satisfied: docutils in c:\users\beach\appdata\roaming\python\python311\site-packages (from fica>=0.4.1->otter-grader) (0.21.2)
# Requirement already satisfied: sphinx in c:\users\beach\appdata\roaming\python\python311\site-packages (from fica>=0.4.1->otter-grader) (8.2.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipywidgets<9.0.0,>=8.1.5->otter-grader) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipywidgets<9.0.0,>=8.1.5->otter-grader) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipywidgets<9.0.0,>=8.1.5->otter-grader) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipywidgets<9.0.0,>=8.1.5->otter-grader) (3.0.15)
# Requirement already satisfied: decorator in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipython->otter-grader) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipython->otter-grader) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipython->otter-grader) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipython->otter-grader) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipython->otter-grader) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipython->otter-grader) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipython->otter-grader) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\beach\appdata\roaming\python\python311\site-packages (from ipython->otter-grader) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jinja2<4.0,>=3.1->otter-grader) (3.0.3)
# Requirement already satisfied: markdown-it-py>=1.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jupytext<2.0.0,>=1.16.4->otter-grader) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\beach\appdata\roaming\python\python311\site-packages (from jupytext<2.0.0,>=1.16.4->otter-grader) (0.5.0)
# Requirement already satisfied: packaging in c:\users\beach\appdata\roaming\python\python311\site-packages (from jupytext<2.0.0,>=1.16.4->otter-grader) (25.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (4.14.2)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (5.8.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (1.5.1)
# Requirement already satisfied: playwright in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbconvert[webpdf]>=6.0.0->otter-grader) (1.55.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbformat>=5.0.0->otter-grader) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbformat>=5.0.0->otter-grader) (4.25.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from pandas>=2.0.0->otter-grader) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from pandas>=2.0.0->otter-grader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from pandas>=2.0.0->otter-grader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\beach\appdata\roaming\python\python311\site-packages (from pandas>=2.0.0->otter-grader) (2025.2)
# Requirement already satisfied: pydantic!=2.0.*,<3,>=2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from python-on-whales<1.0.0,>=0.72.0->otter-grader) (2.11.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from requests<3.0,>=2.31->otter-grader) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\beach\appdata\roaming\python\python311\site-packages (from requests<3.0,>=2.31->otter-grader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from requests<3.0,>=2.31->otter-grader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\beach\appdata\roaming\python\python311\site-packages (from requests<3.0,>=2.31->otter-grader) (2025.8.3)
# Requirement already satisfied: webencodings in c:\users\beach\appdata\roaming\python\python311\site-packages (from bleach[css]!=5.0.0->nbconvert[webpdf]>=6.0.0->otter-grader) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from bleach[css]!=5.0.0->nbconvert[webpdf]>=6.0.0->otter-grader) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->otter-grader) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=5.0.0->otter-grader) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=5.0.0->otter-grader) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=5.0.0->otter-grader) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat>=5.0.0->otter-grader) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.7->nbconvert[webpdf]>=6.0.0->otter-grader) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jupyter-core>=4.7->nbconvert[webpdf]>=6.0.0->otter-grader) (311)
# Requirement already satisfied: mdurl~=0.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from markdown-it-py>=1.0->jupytext<2.0.0,>=1.16.4->otter-grader) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\beach\appdata\roaming\python\python311\site-packages (from nbclient>=0.5.0->nbconvert[webpdf]>=6.0.0->otter-grader) (8.6.3)
# Requirement already satisfied: wcwidth in c:\users\beach\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->otter-grader) (0.2.14)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\beach\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->otter-grader) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from beautifulsoup4->nbconvert[webpdf]>=6.0.0->otter-grader) (2.8)
# Requirement already satisfied: pyee<14,>=13 in c:\users\beach\appdata\roaming\python\python311\site-packages (from playwright->nbconvert[webpdf]>=6.0.0->otter-grader) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from playwright->nbconvert[webpdf]>=6.0.0->otter-grader) (3.2.4)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (3.0.1)
# Requirement already satisfied: babel>=2.13 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from sphinx->fica>=0.4.1->otter-grader) (3.1.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from stack_data->ipython->otter-grader) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from stack_data->ipython->otter-grader) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\beach\appdata\roaming\python\python311\site-packages (from stack_data->ipython->otter-grader) (0.2.3)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert[webpdf]>=6.0.0->otter-grader) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert[webpdf]>=6.0.0->otter-grader) (6.5.2)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\beach\appdata\roaming\python\python311\site-packages (2.3.3)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\beach\appdata\roaming\python\python311\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\beach\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\beach\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy in c:\users\beach\appdata\roaming\python\python311\site-packages (1.16.2)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\beach\appdata\roaming\python\python311\site-packages (from scipy) (2.3.3)
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(run_tests=True)
